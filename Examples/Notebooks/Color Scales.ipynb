// %% [markdown]
// # Color Scales
//
// [![GitHubBadge]][GitHubLink] [![ColabBadge]][ColabLink]
//
// This notebook contains a collection of swatches that show the built-in color scales available in [Plotly.swift](https://github.com/vojtamolda/Plotly.swift) library.
//
//
// [ColabBadge]: https://colab.research.google.com/assets/colab-badge.svg "Run notebook in Google Colab"
// [ColabLink]: https://colab.research.google.com/github/vojtamolda/Plotly.swift/blob/master/Examples/Notebooks/Color%20Scales.ipynb
//
// [GitHubBadge]: https://img.shields.io/badge/|-Edit_on_GitHub-green.svg?logo=github "Edit notebook's source code on GitHub"
// [GitHubLink]: https://github.com/vojtamolda/Plotly.swift/blob/master/Examples/Notebooks/Color%20Scales.ipynb

// %% [markdown]
// ## Setup

// %%
%install '.package(url: "https://github.com/vojtamolda/Plotly.swift.git", .branch("master"))' Plotly
print("\u{001B}[2J") // Clear output

// %%
import Plotly

// %%
%include "EnableIPythonDisplay.swift"

func display(figure: Figure) {
    let htmlContent = try! HTML.create(from: figure,
        plotly: .online, mathJax: .online, document: false)

    let iPythonDisplay = Python.import("IPython.display")
    iPythonDisplay.HTML(htmlContent).display()
}

// %% [markdown]
// ## Most Frequent

// %%
let frequentColorScalesSwatch = ColorScale.swatch()
display(figure: frequentColorScalesSwatch)
// Out:
// <div id='996C9F2D-2145-4C8D-8534-F37CCFA54542'></div>
// <script src='https://cdn.plot.ly/plotly-latest.min.js'></script>
// <script src='https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG'></script>
// <script>
//   Plotly.react('996C9F2D-2145-4C8D-8534-F37CCFA54542',
// ...

// %% [markdown]
// ## Sequential

// %%
let sequentialColorScalesSwatch = ColorScale.Sequential.swatch()
display(figure: sequentialColorScalesSwatch)
// Out:
// <div id='88D3B914-4EAD-4A87-A72D-969EB535C15D'></div>
// <script src='https://cdn.plot.ly/plotly-latest.min.js'></script>
// <script src='https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG'></script>
// <script>
//   Plotly.react('88D3B914-4EAD-4A87-A72D-969EB535C15D',
// ...

// %% [markdown]
// ## Diverging

// %%
let divergingColorScalesSwatch = ColorScale.Diverging.swatch()
display(figure: divergingColorScalesSwatch)
// Out:
// <div id='EAD98227-5363-4990-9C23-EA94700D3C15'></div>
// <script src='https://cdn.plot.ly/plotly-latest.min.js'></script>
// <script src='https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG'></script>
// <script>
//   Plotly.react('EAD98227-5363-4990-9C23-EA94700D3C15',
// ...

// %% [markdown]
// ## Cyclical

// %%
let cyclicalColorScalesSwatch = ColorScale.Cyclical.swatch()
display(figure: cyclicalColorScalesSwatch)
// Out:
// <div id='B8D23BD4-5F0D-4615-BE99-DF8B353485A2'></div>
// <script src='https://cdn.plot.ly/plotly-latest.min.js'></script>
// <script src='https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG'></script>
// <script>
//   Plotly.react('B8D23BD4-5F0D-4615-BE99-DF8B353485A2',
// ...

// %% [markdown]
// ## Ocean

// %%
let oceanColorScalesSwatch = ColorScale.Ocean.swatch()
display(figure: oceanColorScalesSwatch)
// Out:
// <div id='E58970D5-4909-4386-9F09-DB1550D0CD68'></div>
// <script src='https://cdn.plot.ly/plotly-latest.min.js'></script>
// <script src='https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG'></script>
// <script>
//   Plotly.react('E58970D5-4909-4386-9F09-DB1550D0CD68',
// ...

// %% [markdown]
// ## Brewer

// %%
let brewerColorScalesSwatch = ColorScale.Brewer.swatch()
display(figure: brewerColorScalesSwatch)
// Out:
// <div id='E56576DE-F848-466F-B302-24D96F197C39'></div>
// <script src='https://cdn.plot.ly/plotly-latest.min.js'></script>
// <script src='https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG'></script>
// <script>
//   Plotly.react('E56576DE-F848-466F-B302-24D96F197C39',
// ...

// %% [markdown]
// ## Carto

// %%
let cartoColorScalesSwatch = ColorScale.Carto.swatch()
display(figure: cartoColorScalesSwatch)
// Out:
// <div id='01E44062-0DF2-499D-B2B2-759F6345257F'></div>
// <script src='https://cdn.plot.ly/plotly-latest.min.js'></script>
// <script src='https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG'></script>
// <script>
//   Plotly.react('01E44062-0DF2-499D-B2B2-759F6345257F',
// ...

// %% [markdown]
// ## Plotly

// %%
let plotlyColorScalesSwatch = ColorScale.Plotly.swatch()
display(figure: plotlyColorScalesSwatch)
// Out:
// <div id='F169FF91-15CA-4BD2-86A7-0C98365402E2'></div>
// <script src='https://cdn.plot.ly/plotly-latest.min.js'></script>
// <script src='https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG'></script>
// <script>
//   Plotly.react('F169FF91-15CA-4BD2-86A7-0C98365402E2',
// ...

// %% [markdown]
// ## Color Lists

// %%
let colorListsSwatch = ColorList.swatch()
display(figure: colorListsSwatch)
// Out:
// <div id='E1450D1A-63BB-44EF-A854-925FC1EA087E'></div>
// <script src='https://cdn.plot.ly/plotly-latest.min.js'></script>
// <script src='https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG'></script>
// <script>
//   Plotly.react('E1450D1A-63BB-44EF-A854-925FC1EA087E',
// ...
